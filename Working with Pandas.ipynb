# %%
#Importing Library
import pandas as pd
#"Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language."
#One of my favorite things about Pandas is that it allows us to examine and manipulate data sets with short codes.

# %%
#Reading Files
#First, I uploaded the csv file to jupyter notebook and then pulled the data set with pd.read_csv.
student_data = pd.read_csv("Student Mental Health.csv")
pd.set_option('display.max_rows', 5)
student_data
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# ..                   ...                ...   ...                  ...
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 0                       year 1        3.00 - 3.49             No
# 1                       year 2        3.00 - 3.49             No
# ..                         ...                ...            ...
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# ...

# %%
#Data size
#Shape gives us information about row and column sizes.
student_data.shape
# Out:
# (101, 11)

# %%
#First five rows of data
#You can change the number of rows you want to display by entering numbers inside the Head.
student_data.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
#Selecting and processing a specific range of data

# %%
#Age preview
student_data.Age
# Out:
# 0      18.0
# 1      21.0
#        ...
# 99     23.0
# 100    20.0
# Name: Age, Length: 101, dtype: float64

# %%
#Or we can use ['']
student_data['Age']
#Both methods do the same job, but the [] method is more advantageous in multiple functions. For example:
# Out:
# 0      18.0
# 1      21.0
#        ...
# 99     23.0
# 100    20.0
# Name: Age, Length: 101, dtype: float64

# %%
#Specifying column
student_data['Age'][1]
# Out:
# 21.0

# %%
#Indexing
#Indexing allows displaying the specific rows or columns and their ranges that we want to display.
student_data.iloc[0]
# Out:
# Timestamp                                       8/7/2020 12:02
# Choose your gender                                      Female
#                                                      ...
# Do you have Panic attack?                                  Yes
# Did you seek any specialist for a treatment?                No
# Name: 0, Length: 11, dtype: object

# %%
#CGPA
#The following code displays the values in line 5
student_data.iloc[:, 5]
# Out:
# 0      3.00 - 3.49
# 1      3.00 - 3.49
#           ...
# 99     3.50 - 4.00
# 100    3.00 - 3.49
# Name: What is your CGPA?, Length: 101, dtype: object

# %%
#First 4 dates from timestamps
#[], the first part inside square brackets represents the rows, the second part represents the selected column
student_data.iloc[:4, 0]
# Out:
# 0    8/7/2020 12:02
# 1    8/7/2020 12:04
# 2    8/7/2020 12:05
# 3    8/7/2020 12:06
# Name: Timestamp, dtype: object

# %%
#or
student_data.iloc[2:5, 2]
# Out:
# 2    19.0
# 3    22.0
# 4    23.0
# Name: Age, dtype: float64

# %%
#Selecting value by column
student_data.loc[5, 'What is your course?']
# Out:
# 'Engineering'

# %%
#Choosing a specific column range
#More than one column can be selected with loc
student_data.loc[:, ['Age', 'What is your CGPA?','Do you have Anxiety?']]
# Out:
#       Age What is your CGPA? Do you have Anxiety?
# 0    18.0        3.00 - 3.49                   No
# 1    21.0        3.00 - 3.49                  Yes
# ..    ...                ...                  ...
# 99   23.0        3.50 - 4.00                   No
# 100  20.0        3.00 - 3.49                   No
#
# [101 rows x 3 columns]

# %%
# We can change the index we use with the set_index method
student_data.set_index("Age")
# Out:
#                 Timestamp Choose your gender What is your course?  \
# Age
# 18.0       8/7/2020 12:02             Female          Engineering
# 21.0       8/7/2020 12:04               Male    Islamic education
# ...                   ...                ...                  ...
# 23.0  13/07/2020 21:23:57             Female     Pendidikan Islam
# 20.0  18/07/2020 20:16:21               Male   Biomedical science
#
#      Your current year of Study What is your CGPA? Marital status  \
# Age
# 18.0                     year 1        3.00 - 3.49             No
# 21.0                     year 2        3.00 - 3.49             No
# ...                         ...                ...            ...
# 23.0                     year 4        3.50 - 4.00             No
# 20.0                     Year 2        3.00 - 3.49             No
#
#      Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# Age
# ...

# %%
# Conditional Selection
#To find results that contain one or more conditions
student_data.loc[(student_data.Age>=21)&(student_data['Did you seek any specialist for a treatment?']=="Yes")]
# Out:
#          Timestamp Choose your gender   Age What is your course?  \
# 28  8/7/2020 13:58             Female  24.0                  BIT
# 39  8/7/2020 14:56             Female  24.0          Engineering
# 50  8/7/2020 15:27             Female  23.0                  ALA
#
#    Your current year of Study What is your CGPA? Marital status  \
# 28                     Year 3        3.50 - 4.00            Yes
# 39                     Year 2        2.50 - 2.99            Yes
# 50                     year 1        2.50 - 2.99            Yes
#
#    Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 28                     Yes                  Yes                       Yes
# 39                     Yes                   No                       Yes
# 50                     Yes                   No                       Yes
#
#    Did you seek any specialist for a treatment?
# 28                                          Yes
# ...

# %%
#isin
#isin method is used for specifying rows
student_data.loc[student_data.Age.isin([22.0, 24.0])]
# Out:
#               Timestamp Choose your gender   Age What is your course?  \
# 3        8/7/2020 12:06             Female  22.0                 Laws
# 11       8/7/2020 12:39             Female  24.0          Engineering
# ..                  ...                ...   ...                  ...
# 89  13/07/2020 11:54:58               Male  24.0          Engineering
# 94  13/07/2020 17:30:44             Female  24.0                 Fiqh
#
#    Your current year of Study What is your CGPA? Marital status  \
# 3                      year 3        3.00 - 3.49            Yes
# 11                     Year 3        3.50 - 4.00            Yes
# ..                        ...                ...            ...
# 89                     Year 2        2.00 - 2.49             No
# 94                     Year 3           0 - 1.99             No
#
#    Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 3                      Yes                   No                        No
# ...

# %%
#Assigning
#We can assign values to the dataset and change existing values
student_data['year 3'] = 'Year 3'
student_data['year 3']
# Out:
# 0      Year 3
# 1      Year 3
#         ...
# 99     Year 3
# 100    Year 3
# Name: year 3, Length: 101, dtype: object

# %%
#Summary Functions and Maps

#Summary of the student_data
student_data.Age.describe()
# Out:
# count    100.00
# mean      20.53
#           ...
# 75%       23.00
# max       24.00
# Name: Age, Length: 8, dtype: float64

# %%
#For string data
student_data['What is your course?'].describe()
# Out:
# count     101
# unique     49
# top       BCS
# freq       18
# Name: What is your course?, dtype: object

# %%
#Average age
student_data.Age.mean()
# Out:
# 20.53

# %%
#To see unique values of a specific column
student_data['What is your course?'].unique()
# Out:
# array(['Engineering', 'Islamic education', 'BIT', 'Laws', 'Mathemathics',
#        'Pendidikan islam', 'BCS', 'Human Resources', 'Irkhs',
#        'Psychology', 'KENMS', 'Accounting ', 'ENM', 'Marine science',
#        'KOE', 'Banking Studies', 'Business Administration', 'Law',
#        'KIRKHS', 'Usuluddin ', 'TAASL', 'Engine', 'ALA',
#        'Biomedical science', 'koe', 'Kirkhs', 'BENL', 'Benl', 'IT', 'CTS',
#        'engin', 'Econs', 'MHSC', 'Malcom', 'Kop', 'Human Sciences ',
#        'Biotechnology', 'Communication ', 'Diploma Nursing',
#        'Pendidikan Islam ', 'Radiography', 'psychology', 'Fiqh fatwa ',
#        'DIPLOMA TESL', 'Koe', 'Fiqh', 'Islamic Education', 'Nursing ',
#        'Pendidikan Islam'], dtype=object)

# %%
#List of unique values and how often they occur in the dataset with value_counts() method
student_data['What is your course?'].value_counts()
# Out:
# BCS                  18
# Engineering          17
#                      ..
# Islamic education     1
# Pendidikan Islam      1
# Name: What is your course?, Length: 49, dtype: int64

# %%
#Let's continue with openpowerlifting dataset
powerlifting = pd.read_csv("openpowerlifting.csv")
powerlifting
# Out:
#         MeetID              Name Sex   Equipment   Age   Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0  Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0  Mst 40-44
# ...        ...               ...  ..         ...   ...        ...
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN      Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN      Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# 0              59.60            60       NaN        47.63       NaN
# 1              58.51            60       NaN       142.88       NaN
# ...              ...           ...       ...          ...       ...
# 386412        126.73           140       NaN          NaN       NaN
# 386413        129.46           140       NaN          NaN       NaN
#
#         BestBenchKg  Deadlift4Kg  BestDeadliftKg  TotalKg Place   Wilks
# 0             20.41          NaN           70.31   138.35     1  155.05
# ...

# %%
# First five columns
powerlifting.head()
# Out:
#    MeetID              Name Sex   Equipment   Age     Division  BodyweightKg  \
# 0       0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49         59.60
# 1       0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44         58.51
# 2       0       Dawn Bogart   F  Single-ply  42.0  Open Senior         58.51
# 3       0       Dawn Bogart   F         Raw  42.0  Open Senior         58.51
# 4       0      Destiny Dula   F         Raw  18.0   Teen 18-19         63.68
#
#   WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  Deadlift4Kg  \
# 0            60       NaN        47.63       NaN        20.41          NaN
# 1            60       NaN       142.88       NaN        95.25          NaN
# 2            60       NaN       142.88       NaN        95.25          NaN
# 3            60       NaN          NaN       NaN        95.25          NaN
# 4          67.5       NaN          NaN       NaN        31.75          NaN
#
#    BestDeadliftKg  TotalKg Place   Wilks
# ...

# %%
# Maps
# Suppose that we want to remean BodyweightKg column values by using map

powerlifting_bodyweightkg_mean = powerlifting.BodyweightKg.mean()
powerlifting.BodyweightKg.map(lambda p: p-powerlifting_bodyweightkg_mean)

# In this code we subtracted the average value from each body weight. Thus, we can see how much an athlete's body weight is below or above average.
#In Python Pandas, lambda is a function used to operate on a DataFrame. Lambda makes functions more concise.
# Out:
# 0        -27.334912
# 1        -28.424912
#             ...
# 386412    39.795088
# 386413    42.525088
# Name: BodyweightKg, Length: 386414, dtype: float64

# %%
# Maps with def and apply

def remean_bodyweight(kg):
    kg.BodyweightKg = kg.BodyweightKg - powerlifting_bodyweightkg_mean
    return kg
powerlifting.apply(remean_bodyweight, axis='columns')
#We can apply the function we created with Apply( , ) to the dataset.
# Out:
#         MeetID              Name Sex   Equipment   Age   Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0  Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0  Mst 40-44
# ...        ...               ...  ..         ...   ...        ...
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN      Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN      Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# 0         -27.334912            60       NaN        47.63       NaN
# 1         -28.424912            60       NaN       142.88       NaN
# ...              ...           ...       ...          ...       ...
# 386412     39.795088           140       NaN          NaN       NaN
# 386413     42.525088           140       NaN          NaN       NaN
#
#         BestBenchKg  Deadlift4Kg  BestDeadliftKg  TotalKg Place   Wilks
# 0             20.41          NaN           70.31   138.35     1  155.05
# ...

# %%
#Faster way for remeaning bodyweight values
powerlifting_bodyweightkg_mean = powerlifting.BodyweightKg.mean()
powerlifting.BodyweightKg - powerlifting_bodyweightkg_mean
# Out:
# 0        -27.334912
# 1        -28.424912
#             ...
# 386412    39.795088
# 386413    42.525088
# Name: BodyweightKg, Length: 386414, dtype: float64

# %%
#Combining columns
powerlifting.Name + " - " + powerlifting.Sex
# Out:
# 0         Angie Belk Terry - F
# 1              Dawn Bogart - F
#                   ...
# 386412      Jeff Bumanglag - M
# 386413       Shane Hammock - M
# Length: 386414, dtype: object

# %%
# GROUPING AND SORTING

#Group by WeightClassKg
#Just like in SQL :)
powerlifting.groupby('WeightClassKg').WeightClassKg.count()
# Out:
# WeightClassKg
# 100     34233
# 100+       34
#         ...
# 93      17032
# 95         65
# Name: WeightClassKg, Length: 51, dtype: int64

# %%
# Let's run different functions together by using groupby
powerlifting.groupby(['BodyweightKg']).Age.agg([len, min, max,])
# Out:
#               len   min   max
# BodyweightKg
# 15.88           1   7.0   7.0
# 17.24           1   NaN   NaN
# ...           ...   ...   ...
# 240.00          1   NaN   NaN
# 242.40          1  32.0  32.0
#
# [9110 rows x 3 columns]

# %%
#Multi-indexes
powerlifting_multi=powerlifting.groupby(['BodyweightKg','Division']).BestDeadliftKg.agg([max])
powerlifting_multi
# Out:
#                          max
# BodyweightKg Division
# 15.88        Youth     24.95
# 17.24        youth     30.00
# ...                      ...
# 238.00       R-O         NaN
# 240.00       R-M1        NaN
#
# [119588 rows x 1 columns]

# %%
# Different way to do this with lambda and idxmax
powerlifting = powerlifting.dropna()
powerlifting.groupby(['BodyweightKg']).apply(lambda df: df.loc[df.BestDeadliftKg.idxmax()])
#The idxmax() method returns a Series with the index of the maximum value for each column.
# Out:
#               MeetID             Name Sex Equipment   Age      Division  \
# BodyweightKg
# 44.00           7840  Stacia-Al Mahoe   F       Raw  18.0  Junior 18-19
# 45.27             15   Rocky Luedeker   F       Raw  61.0        R Open
# ...              ...              ...  ..       ...   ...           ...
# 169.20          8445   Filipp Obukhov   M     Wraps  23.0          Open
# 181.20          8460   Filipp Obukhov   M     Wraps  23.0          Open
#
#               BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# BodyweightKg
# 44.00                44.00            44     102.5        100.5      70.0
# 45.27                45.27            48      42.5         37.5      33.5
# ...                    ...           ...       ...          ...       ...
# 169.20              169.20          140+     415.0        400.0    -250.0
# 181.20              181.20          140+    -440.5        420.0    -252.5
#
# ...

# %%
# Reseting multi-indexes

powerlifting_multi.reset_index()
# Out:
#         BodyweightKg Division    max
# 0              15.88    Youth  24.95
# 1              17.24    youth  30.00
# ...              ...      ...    ...
# 119586        238.00      R-O    NaN
# 119587        240.00     R-M1    NaN
#
# [119588 rows x 3 columns]

# %%
#Sorting data
#If we want to rank with the best deadlift record
powerlifting_multi= powerlifting_multi.reset_index()
powerlifting_multi.sort_values(by='max')
# Out:
#         BodyweightKg          Division    max
# 117046        153.77          Open Men -357.5
# 82381         100.15  Junior Men 20-23 -350.0
# ...              ...               ...    ...
# 119586        238.00               R-O    NaN
# 119587        240.00              R-M1    NaN
#
# [119588 rows x 3 columns]

# %%
#Descending order by adding 'ascending=False'
powerlifting_multi.sort_values(by='max', ascending=False)
# Out:
#         BodyweightKg Division    max
# 118835        172.82    Heavy  460.4
# 86540         104.00     Open  450.0
# ...              ...      ...    ...
# 119586        238.00      R-O    NaN
# 119587        240.00     R-M1    NaN
#
# [119588 rows x 3 columns]

# %%
# Data Types

powerlifting.dtypes
# Out:
# MeetID      int64
# Name       object
#            ...
# Place      object
# Wilks     float64
# Length: 17, dtype: object

# %%
powerlifting.dtypes
# Out:
# MeetID      int64
# Name       object
#            ...
# Place      object
# Wilks     float64
# Length: 17, dtype: object

# %%
#Converting Data Type
#Astype allows converting an existing data type to another data type.
powerlifting.Age.astype('float64')
# Out:
# 0         47.0
# 1         42.0
#           ...
# 386412     NaN
# 386413     NaN
# Name: Age, Length: 386414, dtype: float64

# %%
#Missing Data
#isnull() allows displaying NaN values in the dataset
powerlifting[pd.isnull(powerlifting.Squat4Kg)]
# Out:
#         MeetID              Name Sex   Equipment   Age   Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0  Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0  Mst 40-44
# ...        ...               ...  ..         ...   ...        ...
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN      Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN      Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# 0              59.60            60       NaN        47.63       NaN
# 1              58.51            60       NaN       142.88       NaN
# ...              ...           ...       ...          ...       ...
# 386412        126.73           140       NaN          NaN       NaN
# 386413        129.46           140       NaN          NaN       NaN
#
#         BestBenchKg  Deadlift4Kg  BestDeadliftKg  TotalKg Place   Wilks
# 0             20.41          NaN           70.31   138.35     1  155.05
# ...

# %%
#Replacing Missing Values
#We can replace this data with fillna()
powerlifting.Squat4Kg.fillna("No Value")
# Out:
# 0         No Value
# 1         No Value
#             ...
# 386412    No Value
# 386413    No Value
# Name: Squat4Kg, Length: 386414, dtype: object

# %%
#Renaming Columns
#The rename method can be used to change column names
powerlifting.rename(columns={'Place': 'Rank'})
# Out:
#         MeetID              Name Sex   Equipment   Age   Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0  Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0  Mst 40-44
# ...        ...               ...  ..         ...   ...        ...
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN      Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN      Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# 0              59.60            60       NaN        47.63       NaN
# 1              58.51            60       NaN       142.88       NaN
# ...              ...           ...       ...          ...       ...
# 386412        126.73           140       NaN          NaN       NaN
# 386413        129.46           140       NaN          NaN       NaN
#
#         BestBenchKg  Deadlift4Kg  BestDeadliftKg  TotalKg Rank   Wilks
# 0             20.41          NaN           70.31   138.35    1  155.05
# ...

# %%
#Renaming Indexes
#and even indexes
powerlifting.rename(index={0: 'first', 1:'second'})
# Out:
#         MeetID              Name Sex   Equipment   Age   Division  \
# first        0  Angie Belk Terry   F       Wraps  47.0  Mst 45-49
# second       0       Dawn Bogart   F  Single-ply  42.0  Mst 40-44
# ...        ...               ...  ..         ...   ...        ...
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN      Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN      Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# first          59.60            60       NaN        47.63       NaN
# second         58.51            60       NaN       142.88       NaN
# ...              ...           ...       ...          ...       ...
# 386412        126.73           140       NaN          NaN       NaN
# 386413        129.46           140       NaN          NaN       NaN
#
#         BestBenchKg  Deadlift4Kg  BestDeadliftKg  TotalKg Place   Wilks
# first         20.41          NaN           70.31   138.35     1  155.05
# ...

# %%
#Joining, Combining Datasets
cnd_youtube = pd.read_csv("CAvideos.csv")
brit_youtube = pd.read_csv("GBvideos.csv")

pd.concat([cnd_youtube, brit_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# ...            ...           ...
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# ...                                                  ...
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 0                   EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1                    iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ...                        ...          ...                       ...
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# ...

# %%
#Let's join the data sets like in SQL. Pandas allows us to join two datasets with short codes.
left = cnd_youtube.set_index(['title', 'trending_date'])
right = brit_youtube.set_index(['title', 'trending_date'])

right.join(left, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# #21 How to go FAST!!! Coaching famous youtuber ... 17.14.11       NLCfRHdi6Ig
#                                                    17.15.11       NLCfRHdi6Ig
# ...                                                                       ...
# 🔥  The 'Avengers: Infinity War' Cast Play ‘HOT ... 18.09.05       PcuRZ3WACBU
#                                                    18.30.04       PcuRZ3WACBU
#
#                                                                  channel_title_CAN  \
# title                                              trending_date
# #21 How to go FAST!!! Coaching famous youtuber ... 17.14.11             Ben Cathro
#                                                    17.15.11             Ben Cathro
# ...                                                                            ...
# ...

# %%
#References:
#https://www.kaggle.com/learn 
#https://www.kaggle.com/datasets/shariful07/student-mental-health
#https://www.kaggle.com/datasets/datasnaek/youtube-new
#https://www.kaggle.com/datasets/dansbecker/powerlifting-database
#https://pandas.pydata.org/
